# %%
import pandas as pd
df = pd.read_excel('top_artis_2022.xlsx')
df
# Out:
#                                               name  \
# 0                          Something in the Orange
# 1                                    Heading South
# 2                               Oklahoma Smokeshow
# 3                                      From Austin
# 4                                        Sun to Me
# ..                                             ...
# 445                                      Soundgasm
# 446                      Immigrant Song - Remaster
# 447                                           Rema
# 448  Bullet With Butterfly Wings - Remastered 2012
# 449                                           Rema
#
#                                                  album                  artis  \
# 0                              Something in the Orange             Zach Bryan
# 1                                        Heading South             Zach Bryan
# 2                                     Summertime Blues             Zach Bryan
# 3                                  American Heartbreak             Zach Bryan
# 4                                  American Heartbreak             Zach Bryan
# ..                                                 ...                    ...
# 445                                       Rave & Roses                   Rema
# 446                        Led Zeppelin III (Remaster)           Led Zeppelin
# 447                                               Rema                  Oyeme
# 448  Mellon Collie And The Infinite Sadness (Deluxe...  The Smashing Pumpkins
# 449                                               Rema              Bebeshito
#
#     release_date  lenght  popularity  acousticness  danceability  energy  \
# 0     2022-04-22  228013          88      0.555000         0.369   0.192
# 1     2019-09-30  171692          83      0.783000         0.680   0.246
# 2     2022-07-15  211739          80      0.095800         0.544   0.573
# 3     2022-05-20  207453          75      0.633000         0.500   0.485
# 4     2022-05-20  163031          82      0.593000         0.505   0.270
# ..           ...     ...         ...           ...           ...     ...
# 445   2022-03-24  204755          69      0.119000         0.805   0.525
# 446         1970  146250          81      0.013000         0.564   0.932
# 447   2020-03-25   72727          41      0.894000         0.297   0.104
# 448         1995  258466          77      0.000056         0.404   0.720
# 449   2022-09-30  160490          27      0.112000         0.841   0.763
#
#      instrumentalness  liveness  loadness  speechiness    tempo  \
# 0            0.000008    0.0954   -12.151       0.0400  175.212
# 1            0.000000    0.1060   -14.112       0.0580  110.230
# 2            0.000000    0.1040    -5.694       0.0356  122.977
# 3            0.000001    0.1070    -7.940       0.0422  109.755
# 4            0.000000    0.1330    -9.165       0.0333   98.721
# ..                ...       ...       ...          ...      ...
# 445          0.002030    0.0779    -7.376       0.0638  100.033
# 446          0.169000    0.3490   -10.068       0.0554  112.937
# 447          0.761000    0.1750   -18.070       0.0307   75.021
# 448          0.836000    0.0466    -9.180       0.0623  121.864
# 449          0.000060    0.0630    -5.622       0.0947  111.010
#
#      time_signature
# 0                 3
# 1                 4
# 2                 4
# 3                 4
# 4                 4
# ..              ...
# 445               4
# 446               4
# 447               1
# 448               4
# 449               4
#
# [450 rows x 15 columns]

# %%
df.sort_values(by=['popularity'], ascending=False)[['name','artis']].head(10)
# Out:
#                                        name          artis
# 50   Creepin' (with The Weeknd & 21 Savage)   Metro Boomin
# 250  Creepin' (with The Weeknd & 21 Savage)   Metro Boomin
# 400           Calm Down (with Selena Gomez)           Rema
# 153                               Anti-Hero   Taylor Swift
# 200                                     PRC     Peso Pluma
# 202                                     AMG  Natanael Cano
# 150                            Cruel Summer   Taylor Swift
# 100                               Kill Bill            SZA
# 102                                  Snooze            SZA
# 161                                cardigan   Taylor Swift

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(16,8))
sns.set(style="whitegrid")

x = df.groupby("name")["popularity"].mean().sort_values(ascending=False).head(10)

ax = sns.barplot(x=x.index, y=x)
ax.set_title('Musik yang paling populer')
ax.set_ylabel('Popularity')
ax.set_xlabel('Judul musik')

plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(16,8))
sns.set(style="whitegrid")

x = df.groupby("artis")["popularity"].mean().sort_values(ascending=False).head(10)

ax = sns.barplot(x=x.index, y=x)
ax.set_title('Artis yang paling populer')
ax.set_ylabel('Popularity')
ax.set_xlabel('Nama Artis')

plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(16,8))
sns.set(style="whitegrid")

cols = ["popularity","acousticness","instrumentalness","speechiness","danceability","energy"]
sns.pairplot(df[cols], height=2.5)
plt.show()

# %%
print(df.dtypes)
# Out:
# name                 object
# album                object
# artis                object
# release_date         object
# lenght                int64
# popularity            int64
# acousticness        float64
# danceability        float64
# energy              float64
# instrumentalness    float64
# liveness            float64
# loadness            float64
# speechiness         float64
# tempo               float64
# time_signature        int64
# dtype: object

# %%
dfnum = df[['lenght','popularity','acousticness','danceability','energy','instrumentalness','liveness','loadness','speechiness','tempo','time_signature']]
dfnum
# Out:
#      lenght  popularity  acousticness  danceability  energy  instrumentalness  \
# 0    228013          88      0.555000         0.369   0.192          0.000008
# 1    171692          83      0.783000         0.680   0.246          0.000000
# 2    211739          80      0.095800         0.544   0.573          0.000000
# 3    207453          75      0.633000         0.500   0.485          0.000001
# 4    163031          82      0.593000         0.505   0.270          0.000000
# ..      ...         ...           ...           ...     ...               ...
# 445  204755          69      0.119000         0.805   0.525          0.002030
# 446  146250          81      0.013000         0.564   0.932          0.169000
# 447   72727          41      0.894000         0.297   0.104          0.761000
# 448  258466          77      0.000056         0.404   0.720          0.836000
# 449  160490          27      0.112000         0.841   0.763          0.000060
#
#      liveness  loadness  speechiness    tempo  time_signature
# 0      0.0954   -12.151       0.0400  175.212               3
# 1      0.1060   -14.112       0.0580  110.230               4
# 2      0.1040    -5.694       0.0356  122.977               4
# 3      0.1070    -7.940       0.0422  109.755               4
# 4      0.1330    -9.165       0.0333   98.721               4
# ..        ...       ...          ...      ...             ...
# 445    0.0779    -7.376       0.0638  100.033               4
# 446    0.3490   -10.068       0.0554  112.937               4
# 447    0.1750   -18.070       0.0307   75.021               1
# 448    0.0466    -9.180       0.0623  121.864               4
# 449    0.0630    -5.622       0.0947  111.010               4
#
# [450 rows x 11 columns]

# %%
plt.figure(figsize=(16,8))
sns.set(style="whitegrid")
corr = dfnum.corr()
sns.heatmap(corr, annot=True,cmap="coolwarm")
plt.show()

# %% [markdown]
# ### clustering data

# %% [markdown]
# ### preprosessing
